# %%
from datetime import *
class BANKSYSTEM:

    def __init__(self,name,accountNo,username):
        self.name=name
        self.accountNo=accountNo
        self.username=username
        self.balance=0
    def confidential(self,password):
        self.password=password
    def transaction(self):
        if "mybank@123" ==self.password:
            print('login successfully')
            d = datetime.now()
            print('account no:', self.accountNo)
            print('your name:', self.name, '\nyour balance:', self.balance, '\n date:', str(d))
        else:
            print("INCORRECT PASSWORD,RETRY or CHOOSE EXIT")
    def deposit(self):
        self.amount = float(input('enter amount to be deposited:Rupees '))
        self.balance += self.amount
        d = datetime.now()
        print('amount deposited:Rupees',self.balance,'\ntransaction date:', str(d))
    def withdraw(self):
        if 'mybank@123' == self.password:
            print('login successfully')
            self.amount = float(input('enter amount to be debited:Rupees '))
            if self.balance >= self.amount:
                self.balance -= self.amount
                d = datetime.now()
                print('Rupees', self.amount, 'is debited from your account')
                print('your balance: rupees ', self.balance, '\ntransaction date:', str(d))
            else:
                print('sorry,your account balance is insufficient')
        else:
            print("INCORRECT PASSWORD,RETRY or CHOOSE EXIT")
B=BANKSYSTEM(input('name:'),input('accountNo:'),input('username:'))
def choice():
    print("Select an option")
    print("0.Transaction\n1.Deposit\n2.Withdraw\n3.Exit")
r1 = choice()
print(r1)
o = int(input("Enter Your Option:"))
while True:
    if o == 0:
        B.confidential(input('password:'))
        B.transaction()
        r0 = choice()
        print(r0)
        o = int(input("Enter Your Option:"))

    elif o == 1:
        B.deposit()
        r2 = choice()
        print(r2)
        o = int(input("Enter Your Option:"))

    elif o == 2:
        B.confidential(input('password:'))
        B.withdraw()
        r3 = choice()
        print(r3)
        o = int(input("Enter Your Option:"))

    elif o == 3:
        print("Thank you,you are exited from the home page.\nvisit again")
        break
    else:
        print('you entered an invalid choice.RETRY')
        r1 = choice()
        print(r1)
        o = int(input("Enter Your Option:"))
else:
    print('RETRY AFTER 1Hr')
# Out:
# name:Simi
# accountNo:2456
# username:Simi
# Select an option
# 0.Transaction
# 1.Deposit
# 2.Withdraw
# 3.Exit
# None
# Enter Your Option:0
# password:mybank@123
# login successfully
# account no: 2456
# your name: Simi
# your balance: 0
#  date: 2024-06-05 02:16:46.781175
# Select an option
# 0.Transaction
# 1.Deposit
# 2.Withdraw
# 3.Exit
# None
# Enter Your Option:1
# enter amount to be deposited:Rupees 4000
# amount deposited:Rupees 4000.0
# transaction date: 2024-06-05 02:17:04.476955
# Select an option
# 0.Transaction
# 1.Deposit
# 2.Withdraw
# 3.Exit
# None
# Enter Your Option:1
# enter amount to be deposited:Rupees 500
# amount deposited:Rupees 4500.0
# transaction date: 2024-06-05 02:17:23.241093
# Select an option
# 0.Transaction
# 1.Deposit
# 2.Withdraw
# 3.Exit
# None
# Enter Your Option:2
# password:mybank@123
# login successfully
# enter amount to be debited:Rupees 3456
# Rupees 3456.0 is debited from your account
# your balance: rupees  1044.0
# transaction date: 2024-06-05 02:17:54.046507
# Select an option
# 0.Transaction
# 1.Deposit
# 2.Withdraw
# 3.Exit
# None
# Enter Your Option:0
# password:mybank@123
# login successfully
# account no: 2456
# your name: Simi
# your balance: 1044.0
#  date: 2024-06-05 02:18:31.397249
# Select an option
# 0.Transaction
# 1.Deposit
# 2.Withdraw
# 3.Exit
# None
# Enter Your Option:2
# password:6gg6gug
# INCORRECT PASSWORD,RETRY or CHOOSE EXIT
# Select an option
# 0.Transaction
# 1.Deposit
# 2.Withdraw
# 3.Exit
# None
# Enter Your Option:5
# you entered an invalid choice.RETRY
# Select an option
# 0.Transaction
# 1.Deposit
# 2.Withdraw
# 3.Exit
# None
# Enter Your Option:2
# password:30000
# INCORRECT PASSWORD,RETRY or CHOOSE EXIT
# Select an option
# 0.Transaction
# 1.Deposit
# 2.Withdraw
# 3.Exit
# None
# Enter Your Option:2
# password:mybank@123
# login successfully
# enter amount to be debited:Rupees 5000
# sorry,your account balance is insufficient
# Select an option
# 0.Transaction
# 1.Deposit
# 2.Withdraw
# 3.Exit
# None
# Enter Your Option:3
# Thank you,you are exited from the home page.
# visit again
